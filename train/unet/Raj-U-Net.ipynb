# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, Activation, MaxPool2D,
    Conv2DTranspose, Concatenate, Input
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras.optimizers import Adam

# %%
# Set seeds for reproducibility
os.environ["PYTHONHASHSEED"] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

# Hyperparameters
batch_size = 1
epochs = 50
height, width = 640, 640  # Ensure height and width are defined
input_shape = (height, width, 3)
lr = 1e-4  # Learning rate

# Define convolution block
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# Define encoder block
def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

# Define decoder block
def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

# Build U-Net model for segmentation
def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    bl = conv_block(p4, 1024)

    dl = decoder_block(bl, s4, 512)
    d2 = decoder_block(dl, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    segmentation_output = Conv2D(1, 1, padding="same", activation="sigmoid", name="segmentation")(d4)
    model = Model(inputs, segmentation_output, name="UNET")
    return model

# Define paths and create directories
data_dir = r"/home/user/unet/data"
files_dir = data_dir

def create_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory {directory} created.")
    else:
        print(f"Directory {directory} already exists.")

create_dir(files_dir)
model_file = os.path.join(files_dir, "unet-model.keras")
log_file = os.path.join(files_dir, "log.csv")

# Function to load and split data
def load_data(data_dir):
    def get_data_paths(subset):
        images = sorted(glob(os.path.join(data_dir, subset, "*.png")))
        masks = sorted(glob(os.path.join(data_dir, subset, "masks", "*.png")))
        return images, masks
    
    train_x, train_y = get_data_paths("train")
    valid_x, valid_y = get_data_paths("val")
    test_x, test_y = get_data_paths("test")

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# Functions to read images and masks
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    return x

# TensorFlow parsing and dataset functions
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# Load the dataset
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(data_dir)
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")

# Create datasets
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

for x, y in valid_dataset:
    print(x.shape, y.shape)
    break

# Build and compile the model
model = build_unet(input_shape)
opt = Adam(learning_rate=lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

model.summary()

# Callbacks for training
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]

# Train the model
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks
)

# Evaluate the model on the test set
model.evaluate(test_dataset)
# Out:
# Directory /home/user/unet/data already exists.
# Train: 401 - 401
# Valid: 86 - 86
# Test: 86 - 86
# (1, 640, 640, 3) (1, 640, 640, 1)
# Model: "UNET"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 640, 640,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 640, 640,  │      1,792 │ input_layer_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 640, 640,  │        256 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 640, 640,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 640, 640,  │     36,928 │ activation_90[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 640, 640,  │        256 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 640, 640,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 320, 320,  │          0 │ activation_91[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 320, 320,  │     73,856 │ max_pooling2d_20… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 320, 320,  │        512 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 320, 320,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 320, 320,  │    147,584 │ activation_92[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 320, 320,  │        512 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, 320, 320,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 160, 160,  │          0 │ activation_93[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 160, 160,  │    295,168 │ max_pooling2d_21… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 160, 160,  │      1,024 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_94       │ (None, 160, 160,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 160, 160,  │    590,080 │ activation_94[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 160, 160,  │      1,024 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_95       │ (None, 160, 160,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 80, 80,    │          0 │ activation_95[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 80, 80,    │  1,180,160 │ max_pooling2d_22… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │      2,048 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_96       │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 80, 80,    │  2,359,808 │ activation_96[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │      2,048 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_97       │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 40, 40,    │          0 │ activation_97[0]… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 40, 40,    │  4,719,616 │ max_pooling2d_23… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │      4,096 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_98       │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 40, 40,    │  9,438,208 │ activation_98[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │      4,096 │ conv2d_99[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_99       │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 80, 80,    │  2,097,664 │ activation_99[0]… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 80, 80,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_97[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 80, 80,    │  4,719,104 │ concatenate_20[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │      2,048 │ conv2d_100[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_100      │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 80, 80,    │  2,359,808 │ activation_100[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │      2,048 │ conv2d_101[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_101      │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_21 │ (None, 160, 160,  │    524,544 │ activation_101[0… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 160, 160,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_95[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 160, 160,  │  1,179,904 │ concatenate_21[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 160, 160,  │      1,024 │ conv2d_102[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_102      │ (None, 160, 160,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 160, 160,  │    590,080 │ activation_102[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 160, 160,  │      1,024 │ conv2d_103[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_103      │ (None, 160, 160,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_22 │ (None, 320, 320,  │    131,200 │ activation_103[0… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 320, 320,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_93[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 320, 320,  │    295,040 │ concatenate_22[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 320, 320,  │        512 │ conv2d_104[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_104      │ (None, 320, 320,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_105 (Conv2D) │ (None, 320, 320,  │    147,584 │ activation_104[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 320, 320,  │        512 │ conv2d_105[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_105      │ (None, 320, 320,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_23 │ (None, 640, 640,  │     32,832 │ activation_105[0… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 640, 640,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_91[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 640, 640,  │     73,792 │ concatenate_23[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 640, 640,  │        256 │ conv2d_106[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_106      │ (None, 640, 640,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_107 (Conv2D) │ (None, 640, 640,  │     36,928 │ activation_106[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 640, 640,  │        256 │ conv2d_107[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_107      │ (None, 640, 640,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation        │ (None, 640, 640,  │         65 │ activation_107[0… │
# │ (Conv2D)            │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,055,297 (118.47 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)
# Epoch 1/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7561 - loss: 0.5261
# Epoch 1: val_loss improved from inf to 0.48134, saving model to /home/user/unet/data/unet-model.keras
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 157s 299ms/step - accuracy: 0.7561 - loss: 0.5260 - val_accuracy: 0.8378 - val_loss: 0.4813 - learning_rate: 1.0000e-04
# Epoch 2/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.7883 - loss: 0.4300
# Epoch 2: val_loss improved from 0.48134 to 0.38120, saving model to /home/user/unet/data/unet-model.keras
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 99s 247ms/step - accuracy: 0.7883 - loss: 0.4300 - val_accuracy: 0.8469 - val_loss: 0.3812 - learning_rate: 1.0000e-04
# Epoch 3/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.7902 - loss: 0.4259
# Epoch 3: val_loss improved from 0.38120 to 0.36615, saving model to /home/user/unet/data/unet-model.keras
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 112s 279ms/step - accuracy: 0.7902 - loss: 0.4259 - val_accuracy: 0.8517 - val_loss: 0.3662 - learning_rate: 1.0000e-04
# Epoch 4/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7915 - loss: 0.4224
# Epoch 4: val_loss did not improve from 0.36615
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 183s 456ms/step - accuracy: 0.7915 - loss: 0.4224 - val_accuracy: 0.8532 - val_loss: 0.3747 - learning_rate: 1.0000e-04
# Epoch 5/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7920 - loss: 0.4209
# Epoch 5: val_loss did not improve from 0.36615
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 93s 232ms/step - accuracy: 0.7920 - loss: 0.4209 - val_accuracy: 0.8196 - val_loss: 0.3708 - learning_rate: 1.0000e-04
# Epoch 6/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7920 - loss: 0.4203
# Epoch 6: val_loss improved from 0.36615 to 0.36602, saving model to /home/user/unet/data/unet-model.keras
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.7920 - loss: 0.4203 - val_accuracy: 0.8210 - val_loss: 0.3660 - learning_rate: 1.0000e-04
# Epoch 7/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7937 - loss: 0.4186
# Epoch 7: val_loss did not improve from 0.36602
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 96s 240ms/step - accuracy: 0.7937 - loss: 0.4186 - val_accuracy: 0.8091 - val_loss: 0.3731 - learning_rate: 1.0000e-04
# Epoch 8/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7933 - loss: 0.4182
# Epoch 8: val_loss did not improve from 0.36602
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.7933 - loss: 0.4182 - val_accuracy: 0.8291 - val_loss: 0.3726 - learning_rate: 1.0000e-04
# Epoch 9/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7937 - loss: 0.4174
# Epoch 9: val_loss did not improve from 0.36602
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.7937 - loss: 0.4174 - val_accuracy: 0.8264 - val_loss: 0.3755 - learning_rate: 1.0000e-04
# Epoch 10/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7947 - loss: 0.4167
# Epoch 10: val_loss did not improve from 0.36602
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.7947 - loss: 0.4167 - val_accuracy: 0.8259 - val_loss: 0.3697 - learning_rate: 1.0000e-04
# Epoch 11/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7842 - loss: 0.4179
# Epoch 11: val_loss improved from 0.36602 to 0.35059, saving model to /home/user/unet/data/unet-model.keras
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 101s 251ms/step - accuracy: 0.7842 - loss: 0.4179 - val_accuracy: 0.8453 - val_loss: 0.3506 - learning_rate: 1.0000e-05
# Epoch 12/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7958 - loss: 0.4124
# Epoch 12: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 241ms/step - accuracy: 0.7958 - loss: 0.4124 - val_accuracy: 0.8429 - val_loss: 0.3567 - learning_rate: 1.0000e-05
# Epoch 13/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7993 - loss: 0.4107
# Epoch 13: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 98s 243ms/step - accuracy: 0.7993 - loss: 0.4107 - val_accuracy: 0.8378 - val_loss: 0.3639 - learning_rate: 1.0000e-05
# Epoch 14/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8008 - loss: 0.4098
# Epoch 14: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 98s 244ms/step - accuracy: 0.8007 - loss: 0.4098 - val_accuracy: 0.8340 - val_loss: 0.3704 - learning_rate: 1.0000e-05
# Epoch 15/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8018 - loss: 0.4089
# Epoch 15: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 98s 244ms/step - accuracy: 0.8018 - loss: 0.4089 - val_accuracy: 0.8296 - val_loss: 0.3743 - learning_rate: 1.0000e-05
# Epoch 16/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8012 - loss: 0.4092
# Epoch 16: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8012 - loss: 0.4092 - val_accuracy: 0.8315 - val_loss: 0.3670 - learning_rate: 1.0000e-06
# Epoch 17/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8039 - loss: 0.4070
# Epoch 17: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 98s 244ms/step - accuracy: 0.8039 - loss: 0.4070 - val_accuracy: 0.8317 - val_loss: 0.3674 - learning_rate: 1.0000e-06
# Epoch 18/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8047 - loss: 0.4063
# Epoch 18: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8047 - loss: 0.4063 - val_accuracy: 0.8317 - val_loss: 0.3683 - learning_rate: 1.0000e-06
# Epoch 19/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8052 - loss: 0.4059
# Epoch 19: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8052 - loss: 0.4059 - val_accuracy: 0.8315 - val_loss: 0.3693 - learning_rate: 1.0000e-06
# Epoch 20/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8055 - loss: 0.4056
# Epoch 20: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8055 - loss: 0.4056 - val_accuracy: 0.8314 - val_loss: 0.3692 - learning_rate: 1.0000e-07
# Epoch 21/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8056 - loss: 0.4056
# Epoch 21: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8055 - loss: 0.4056 - val_accuracy: 0.8314 - val_loss: 0.3693 - learning_rate: 1.0000e-07
# Epoch 22/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8056 - loss: 0.4055
# Epoch 22: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8056 - loss: 0.4055 - val_accuracy: 0.8314 - val_loss: 0.3694 - learning_rate: 1.0000e-07
# Epoch 23/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8057 - loss: 0.4055
# Epoch 23: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8057 - loss: 0.4055 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-07
# Epoch 24/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 24: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-08
# Epoch 25/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 25: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 98s 244ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-08
# Epoch 26/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 26: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-08
# Epoch 27/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 27: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-08
# Epoch 28/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 28: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-09
# Epoch 29/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 29: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-09
# Epoch 30/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 30: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 243ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-09
# Epoch 31/50
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8057 - loss: 0.4054
# Epoch 31: val_loss did not improve from 0.35059
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 97s 242ms/step - accuracy: 0.8057 - loss: 0.4054 - val_accuracy: 0.8314 - val_loss: 0.3695 - learning_rate: 1.0000e-09
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.8339 - loss: 0.3311
# [0.33091747760772705, 0.8394681215286255]

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.8263 - loss: 0.3772
# Test Loss: 0.372972697019577
# Test Accuracy: 0.8298653960227966
